# %%
from ydata_profiling import ProfileReport
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
PATH_DATA = os.getenv("PATH_DATA")

df = pd.read_csv(f"..{PATH_DATA}/earthquake_data.csv")

# %%
report = ProfileReport(df, title="Earthquake Data Profiling Report", explorative=True)
report.to_file("../doc/earthquake_data_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 19/19 [00:01<00:00, 16.74it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
